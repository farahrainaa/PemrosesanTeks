# %% [markdown]
# <a href="https://colab.research.google.com/github/farahrainaa/PemrosesanTeks/blob/main/ProjekAkhir/ReviewCamScanner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.intsig.camscanner',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data
# Out:
#                                  reviewId             userName  \
# 0    b99d73a6-6f15-4c49-8262-9c9371b0e395  Igede krista Syalom
# 1    c0955587-c6a3-44bd-a0a3-861d75d38b20       Yosi Muhamad R
# 2    cdf96fca-37e4-430f-bf48-3c7166225f6c   Dayan Rifqy Nujaba
# 3    781845a8-ac5c-4f48-942c-57711de14bed          Angki Rizki
# 4    9b6a16f6-40c0-4189-b13f-dcf1fee550d9  Febriana S. Tinamba
# ..                                    ...                  ...
# 995  6f9394ad-7a9d-41ac-94a7-c87222722495     Nuramala Marytin
# 996  7488a320-bfab-4f2e-8457-8ecdb2a54881       Athira Fauziah
# 997  485f21b3-32b8-4b6c-8c3d-1d22a4acf642     RajaAbangGanteng
# 998  e7c2c6b7-54b3-4e55-8aef-b66a9cf432c0        Ahmad Cholidi
# 999  58968e55-2c25-48e1-b37c-30f5834dba31     Muhamad Suhendra
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a/ACg8oc...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    Iklan nya banyak sekali sampai 1 menit. Tiap b...      1             43
# 1    Terimakasih buat aplikasi ini yg sangat bergun...      5              3
# 2    Iklannya ga kira-kira kalo mau ngasih, ganggu ...      2             19
# 3    Saya pengguna CS dari tahun 2019. Saya terbant...      3             31
# 4    Iklan terlalu banyak. sekali muncul bisa 2 ikl...      1              9
# ..                                                 ...    ...            ...
# 995  Aplikasi nya sangat membantu untuk kegiatan do...      5              4
# 996  Membantu sekali dalam mengscan dokumen yg kura...      5              4
# 997  Bagus, berguna sekali untuk ke alfa dan Indoma...      5              0
# 998                          Sangat membantu pekerjaan      5              0
# 999                       Apk bagus berkualitas tinggi      5              0
#
#     reviewCreatedVersion                  at  \
# 0      6.69.0.2407230000 2024-08-19 03:34:07
# 1      6.73.0.2409260000 2024-10-04 09:30:02
# 2      6.72.5.2409050000 2024-09-19 22:46:51
# 3      6.69.0.2407230000 2024-08-09 03:34:45
# 4      6.72.5.2409050000 2024-09-19 00:41:16
# ..                   ...                 ...
# 995      5.25.5.20200928 2020-10-26 07:29:45
# 996    6.64.1.2405070000 2024-05-20 13:56:10
# 997    6.69.0.2407230000 2024-07-31 08:56:17
# 998    6.70.0.2408080000 2024-08-27 22:30:29
# 999    6.70.0.2408080000 2024-09-27 05:25:09
#
#                                           replyContent           repliedAt  \
# 0    Sorry that we have to monetize via advertising... 2024-08-21 09:01:34
# 1                                                 None                 NaT
# 2    Please accept our apologies for the inconvenie... 2024-09-20 11:00:45
# 3    Hello, could you please describe the issue you... 2024-08-09 10:00:51
# 4    Sorry that we have to monetize via advertising... 2024-09-19 03:00:40
# ..                                                 ...                 ...
# 995                                               None                 NaT
# 996                                               None                 NaT
# 997                                               None                 NaT
# 998                                               None                 NaT
# 999                                               None                 NaT
#
#             appVersion
# 0    6.69.0.2407230000
# 1    6.73.0.2409260000
# 2    6.72.5.2409050000
# 3    6.69.0.2407230000
# 4    6.72.5.2409050000
# ..                 ...
# 995    5.25.5.20200928
# 996  6.64.1.2405070000
# 997  6.69.0.2407230000
# 998  6.70.0.2408080000
# 999  6.70.0.2408080000
#
# [1000 rows x 11 columns]

# %%
scrappeddata1 = data[['userName','content','score','at']]
sorteddata = scrappeddata1.sort_values(by='at', ascending=False)
sorteddata.head()
# Out:
#             userName                                            content  \
# 1     Yosi Muhamad R  Terimakasih buat aplikasi ini yg sangat bergun...
# 110  Abdillah Nurdin             Kebanyakan iklan dan sangat menggangu,
# 501      Boenk Boenk                         Sangat membantu trimakasih
# 986    noor imansyah                 mantap sekali sangat membantu saya
# 135   Imran Sholihin                              Keren dengan fiturnya
#
#      score                  at
# 1        5 2024-10-04 09:30:02
# 110      1 2024-10-04 05:55:54
# 501      5 2024-10-04 02:38:57
# 986      5 2024-10-03 21:55:30
# 135      5 2024-10-03 17:35:43

# %%
sorteddata['Year'] = sorteddata['at'].dt.year
sorteddata['Month'] = sorteddata['at'].dt.month
sorteddata['Day'] = sorteddata['at'].dt.day

# %%
sorteddata
# Out:
#             userName                                            content  \
# 1     Yosi Muhamad R  Terimakasih buat aplikasi ini yg sangat bergun...
# 110  Abdillah Nurdin             Kebanyakan iklan dan sangat menggangu,
# 501      Boenk Boenk                         Sangat membantu trimakasih
# 986    noor imansyah                 mantap sekali sangat membantu saya
# 135   Imran Sholihin                              Keren dengan fiturnya
# ..               ...                                                ...
# 969  Pengguna Google  Aplikasi ini sangat berguna disaat ada mata ku...
# 675  Pengguna Google  Membantu banget dalam pembuatan dengan format ...
# 343  Pengguna Google  Aplikasi nya sgt membantu dlm melakukan scanni...
# 709  Pengguna Google  Saya masih kesulitan untuk menyimpan hasil sca...
# 707  Pengguna Google  Sangat membantu bilamana tidak ada scanner. Ha...
#
#      score                  at  Year  Month  Day
# 1        5 2024-10-04 09:30:02  2024     10    4
# 110      1 2024-10-04 05:55:54  2024     10    4
# 501      5 2024-10-04 02:38:57  2024     10    4
# 986      5 2024-10-03 21:55:30  2024     10    3
# 135      5 2024-10-03 17:35:43  2024     10    3
# ..     ...                 ...   ...    ...  ...
# 969      5 2018-09-26 17:18:31  2018      9   26
# 675      5 2018-09-23 10:45:13  2018      9   23
# 343      5 2018-09-22 03:35:52  2018      9   22
# 709      3 2018-09-21 03:12:29  2018      9   21
# 707      5 2018-09-16 13:17:04  2018      9   16
#
# [1000 rows x 7 columns]

# %%
df = sorteddata[['userName','content','score','Year','Month','Day']]
df
# Out:
#             userName                                            content  \
# 1     Yosi Muhamad R  Terimakasih buat aplikasi ini yg sangat bergun...
# 110  Abdillah Nurdin             Kebanyakan iklan dan sangat menggangu,
# 501      Boenk Boenk                         Sangat membantu trimakasih
# 986    noor imansyah                 mantap sekali sangat membantu saya
# 135   Imran Sholihin                              Keren dengan fiturnya
# ..               ...                                                ...
# 969  Pengguna Google  Aplikasi ini sangat berguna disaat ada mata ku...
# 675  Pengguna Google  Membantu banget dalam pembuatan dengan format ...
# 343  Pengguna Google  Aplikasi nya sgt membantu dlm melakukan scanni...
# 709  Pengguna Google  Saya masih kesulitan untuk menyimpan hasil sca...
# 707  Pengguna Google  Sangat membantu bilamana tidak ada scanner. Ha...
#
#      score  Year  Month  Day
# 1        5  2024     10    4
# 110      1  2024     10    4
# 501      5  2024     10    4
# 986      5  2024     10    3
# 135      5  2024     10    3
# ..     ...   ...    ...  ...
# 969      5  2018      9   26
# 675      5  2018      9   23
# 343      5  2018      9   22
# 709      3  2018      9   21
# 707      5  2018      9   16
#
# [1000 rows x 6 columns]

# %%
sentimen = []
for index, row in df.iterrows():
    if row['score'] > 3 :
        sentimen.append(1)
    elif row['score'] == 3:
        sentimen.append(0)
    else:
        sentimen.append(-1)
df['sentiment'] = sentimen
df.head()
# Out:
#             userName                                            content  \
# 1     Yosi Muhamad R  Terimakasih buat aplikasi ini yg sangat bergun...
# 110  Abdillah Nurdin             Kebanyakan iklan dan sangat menggangu,
# 501      Boenk Boenk                         Sangat membantu trimakasih
# 986    noor imansyah                 mantap sekali sangat membantu saya
# 135   Imran Sholihin                              Keren dengan fiturnya
#
#      score  Year  Month  Day  sentiment
# 1        5  2024     10    4          1
# 110      1  2024     10    4         -1
# 501      5  2024     10    4          1
# 986      5  2024     10    3          1
# 135      5  2024     10    3          1

# %%
df.to_csv("review_cam_scanner.csv", index = False)

# %%
import pandas as pd
df = pd.read_csv('/content/review_cam_scanner.csv')
df.head()
# Out:
#           userName                                            content  score  \
# 0   Yosi Muhamad R  Terimakasih buat aplikasi ini yg sangat bergun...      5
# 1  Abdillah Nurdin             Kebanyakan iklan dan sangat menggangu,      1
# 2      Boenk Boenk                         Sangat membantu trimakasih      5
# 3    noor imansyah                 mantap sekali sangat membantu saya      5
# 4   Imran Sholihin                              Keren dengan fiturnya      5
#
#    Year  Month  Day  sentiment
# 0  2024     10    4          1
# 1  2024     10    4         -1
# 2  2024     10    4          1
# 3  2024     10    3          1
# 4  2024     10    3          1
